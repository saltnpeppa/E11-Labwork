# %%
import numpy as np
import pandas as pd
import time
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import math
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from IPython import display

from scipy.stats import norm
import statistics

# %%
data_indoor = pd.read_csv("/Users/matthewfeizbakhsh/Documents/GitHub/E11-Labwork/1630711461.csv")
data_outdoor = pd.read_csv("/Users/matthewfeizbakhsh/Documents/GitHub/E11-Labwork/1630712128.csv")

# %%
data_indoor.describe()
# Out:
#        Temperature     Pressure   Relative_Humidity   Air_Quality_PM1  \
# count   267.000000   267.000000          267.000000             267.0
# mean     81.051581  1002.839457           33.828787               1.0
# std       0.267014     0.020351            0.270230               0.0
# min      80.562000  1002.772000           33.068000               1.0
# 25%      80.924000  1002.825000           33.640000               1.0
# 50%      81.066000  1002.840000           33.821000               1.0
# 75%      81.185000  1002.854000           33.997500               1.0
# max      81.845000  1002.895000           34.423000               1.0
#
#         Air_Quality_PM2.5   Air_Quality_PM10   Timestamp
# count               267.0              267.0  267.000000
# mean                  2.0                3.0  150.483146
# std                   0.0                0.0   86.994051
# min                   2.0                3.0    1.000000
# ...

# %%
data_outdoor.describe()
# Out:
#        Temperature     Pressure   Relative_Humidity   Air_Quality_PM1  \
# count   266.000000   266.000000          266.000000             266.0
# mean     95.372523  1002.340722           19.759098               1.0
# std       2.659555     0.028566            1.737347               0.0
# min      89.509000  1002.281000           17.625000               1.0
# 25%      93.254500  1002.321000           18.355250               1.0
# 50%      96.202000  1002.340500           19.309000               1.0
# 75%      97.675750  1002.361000           20.806250               1.0
# max      98.457000  1002.422000           23.793000               1.0
#
#         Air_Quality_PM2.5   Air_Quality_PM10   Timestamp
# count               266.0              266.0  266.000000
# mean                  2.0                3.0  150.093985
# std                   0.0                0.0   86.783588
# min                   2.0                3.0    1.000000
# ...

# %%
temp_data_indoor = data_indoor.loc[:, "Temperature"]
timestamp_indoor = data_indoor.loc[:, " Timestamp"]
pressure_indoor = data_indoor.loc[:, " Pressure"]
relative_humidity_indoor = data_indoor.loc[:, " Relative_Humidity"]
air_quality1_indoor = data_indoor.loc[:, " Air_Quality_PM1"]
air_quality2_indoor = data_indoor.loc[:, " Air_Quality_PM2.5"]
air_quality3_indoor = data_indoor.loc[:, " Air_Quality_PM10"]

temp_data_outdoor = data_outdoor.loc[:, "Temperature"]
timestamp_outdoor = data_outdoor.loc[:, " Timestamp"]
pressure_outdoor = data_outdoor.loc[:, " Pressure"]
relative_humidity_outdoor = data_outdoor.loc[:, " Relative_Humidity"]
air_quality1_outdoor = data_outdoor.loc[:, " Air_Quality_PM1"]
air_quality2_outdoor = data_outdoor.loc[:, " Air_Quality_PM2.5"]
air_quality3_outdoor = data_outdoor.loc[:, " Air_Quality_PM10"]

# %%
plt.plot(temp_data_indoor)
plt.plot(temp_data_outdoor)
plt.ylabel("Degrees Farenheit")
plt.title("Temperature Vs. Time")



plt.show()

# %%
plt.plot(pressure_indoor)
plt.plot(pressure_outdoor)
plt.ylabel("Pascals")
plt.title("Pressure Vs. Time")
plt.show()

# %%
plt.plot(relative_humidity_indoor)
plt.plot(relative_humidity_outdoor)
plt.ylabel("Relative Humidity Percent")
plt.title("Relative Humidity Vs. Time")
plt.show()

# %%
plt.plot(air_quality1_indoor)
plt.plot(air_quality1_outdoor)
plt.ylabel("Air Quality PM1")
plt.title("Air Quality PM1 Vs. Time")
plt.show()

# %%
plt.plot(air_quality2_indoor)
plt.plot(air_quality2_outdoor)
plt.ylabel("Air Quality PM2.5")
plt.title("Air Quality PM2.5 Vs. Time")
plt.show()

# %%
plt.plot(air_quality3_indoor)
plt.plot(air_quality3_outdoor)
plt.ylabel("Air Quality PM10")
plt.title("Air Quality PM10 Vs. Time")
plt.show()

# %%
plt.hist(temp_data_indoor, bins = 25)
plt.hist(temp_data_outdoor, bins = 25)
plt.ylabel('Frequency')
plt.xlabel('Temperature in Farenheit')
plt.show()

# %%
plt.hist(pressure_indoor, bins = 15)
plt.hist(pressure_outdoor, bins = 15)
plt.ylabel('Frequency')
plt.xlabel('Pressure in Pascals')
plt.title("Pressure Vs. Time")

plt.show()

# %%
plt.hist(relative_humidity_indoor, bins = 15)
plt.hist(relative_humidity_outdoor, bins = 15)
plt.ylabel('Frequency')
plt.xlabel('Percent Relative Humidity')



plt.show()
